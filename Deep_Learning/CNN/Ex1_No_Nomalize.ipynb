# %% [markdown]
# 1. Load dataset from sklearn
# 2. Split dataset: 80-20
# 3. Normalize
# 4. Design and train network
# 5. Evaluate the trained model

# %%
import numpy as np
import matplotlib.pyplot as plt
# Step 1. Load dataset
# Load the mnist dataset using keras
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)

# Show sample images
# show one example in training set
idx = 150
x = X_train[idx, :]
print
y = y_train[idx]
plt.figure()
plt.subplot(1, 2, 1)
plt.imshow(np.reshape(x, (28,28)), cmap=plt.cm.gray)
plt.title('Corresponding label: %i\n' % y, fontsize=20)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Text(0.5, 1.0, 'Corresponding label: 4\n')

# %%
# Step 2. Split data for training and testing
# Step 2 is not necessary since the dataset was divided into training and test set
# show the number of training images and test images
print("Number of training images:", len(y_train))
print("Number of test images:", len(y_test))

# # Step 3. Normalize the feature values
# X_train = X_train.astype('float32')
# X_test = X_test.astype('float32')
# X_train /= 255
# X_test /= 255
# Out:
# Number of training images: 60000
# Number of test images: 10000

# %%
# Step 4. Build neural network model
from sklearn.neural_network import MLPClassifier

# Size of input layer = 8
# Number of hidden layers = 1
# Size of hidden layer = 2
# Size of output layer = 1
model = MLPClassifier(
    hidden_layer_sizes=(2),
    activation='relu',
    learning_rate_init=0.001,
    max_iter=2000,
    random_state=2,
    verbose=True
)

# %%
# Step 5. Train the designed model
model.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 2.47324677
# Iteration 2, loss = 2.31464925
# Iteration 3, loss = 2.30389960
# Iteration 4, loss = 2.29944885
# Iteration 5, loss = 2.29567877
# Iteration 6, loss = 2.28907332
# Iteration 7, loss = 2.27938508
# Iteration 8, loss = 2.26102797
# Iteration 9, loss = 2.22186088
# Iteration 10, loss = 2.12678031
# Iteration 11, loss = 2.07780974
# Iteration 12, loss = 2.04969604
# Iteration 13, loss = 2.01911346
# Iteration 14, loss = 1.95439125
# Iteration 15, loss = 1.87724399
# Iteration 16, loss = 1.83068407
# Iteration 17, loss = 1.79983396
# Iteration 18, loss = 1.78442669
# Iteration 19, loss = 1.76973031
# Iteration 20, loss = 1.76114010
# Iteration 21, loss = 1.75350186
# Iteration 22, loss = 1.74702317
# Iteration 23, loss = 1.74171260
# Iteration 24, loss = 1.73604891
# Iteration 25, loss = 1.73144295
# Iteration 26, loss = 1.72754873
# Iteration 27, loss = 1.72639607
# Iteration 28, loss = 1.72298870
# Iteration 29, loss = 1.72111199
# Iteration 30, loss = 1.71772981
# Iteration 31, loss = 1.71158541
# Iteration 32, loss = 1.69593471
# Iteration 33, loss = 1.67193917
# Iteration 34, loss = 1.65607850
# Iteration 35, loss = 1.64645807
# Iteration 36, loss = 1.63765914
# Iteration 37, loss = 1.62988285
# Iteration 38, loss = 1.62482402
# Iteration 39, loss = 1.61083758
# Iteration 40, loss = 1.59981383
# Iteration 41, loss = 1.59516897
# Iteration 42, loss = 1.59231292
# Iteration 43, loss = 1.59046894
# Iteration 44, loss = 1.58687949
# Iteration 45, loss = 1.58764589
# Iteration 46, loss = 1.58651075
# Iteration 47, loss = 1.58481788
# Iteration 48, loss = 1.58334719
# Iteration 49, loss = 1.58147648
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=2, max_iter=2000, random_state=2, verbose=True)

# %%
# Show the weights and biases of the trained network
print("Weights = ", model. coefs_ )
print("Biases = ", model. intercepts_)
print("Size of output layer: ", model.n_outputs_)
print("Activation function of output layer: ", model. out_activation_)

# Show the plot of the loss curve
import matplotlib.pyplot as plt
loss_values = model.loss_curve_
plt.plot(loss_values)
plt.xlabel("Iteration")
plt.ylabel("Cost value")
plt.show()
# Out:
# Weights =  [array([[ 4.74458954e-315, -4.36287629e-315],
#        [ 1.41465805e-315,  4.55753128e-315],
#        [-1.26358952e-315, -3.09432362e-315],
#        ...,
#        [-5.06665940e-316,  1.96025029e-315],
#        [ 6.21429663e-316, -3.16933606e-315],
#        [-2.24468215e-315,  1.14391283e-315]]), array([[ 1.27784422e-01,  1.84400620e-01,  1.49342540e-01,
#          2.00046063e-01,  2.18186926e-01,  2.00274999e-01,
#          1.04231022e-01,  2.26840546e-01,  2.03749227e-01,
#          2.23984653e-01],
#        [-3.61108661e-27, -1.65559719e-09,  5.17686625e-01,
#          6.28092499e-01, -1.60017888e-19,  3.15968081e-01,
#         -1.22367185e-27,  5.54988857e-20, -2.03103667e-01,
#         -4.99208210e-29]])]
# Biases =  [array([12.12804012, -0.02622998]), array([ 3.40338028,  2.02773069,  3.18305121,  0.69573184, -2.09377267,
#         0.53345818,  3.49156568, -5.04957034,  0.05971997, -3.81288929])]
# Size of output layer:  10
# Activation function of output layer:  softmax

# %%
# Step 6. Evaluate the trained neural network
from sklearn.metrics import accuracy_score

# compute the accuracy of the trained network on the training set
predict_train = model.predict(X_train)
accuracy_on_training_set = accuracy_score(y_train, predict_train)
print("Accuracy on the training set: %.2f %%" % (100 * accuracy_on_training_set))

# compute the accuracy of the trained network on the test set
predict_test = model.predict(X_test)
accuracy_on_test_set = accuracy_score(y_test, predict_test)
print("Accuracy on the test set: %.2f %%" % (100 * accuracy_on_test_set))
# Out:
# Accuracy on the training set: 38.83 %
# Accuracy on the test set: 38.43 %

# %%
# Change hidden layer to (64, 64, 32)

# Size of input layer = 8
# Number of hidden layers = 1
# Size of hidden layer = 3, the first is 64 neurons, the second is 64 and the third is 32
# Size of output layer = 1
model = MLPClassifier(
    hidden_layer_sizes=(64, 64, 32),
    activation='relu',
    learning_rate_init=0.001,
    max_iter=2000,
    random_state=2,
    verbose=True)

# Step 5. Train the designed model
model.fit(X_train, y_train)

# Show the weights and biases of the trained network
print('Weights = ', model.coefs_)
print('Biases = ', model.intercepts_)
print('Size of output layer: ', model.n_outputs_)
print('Activation function of output layer: ', model.out_activation_)

# Show the plot of the loss curve
loss_values = model.loss_curve_
plt.plot(loss_values)
plt.xlabel('Iteration')
plt.ylabel('Cost value')
plt.show()

# Step 6. Evaluate the trained neural network
from sklearn.metrics import accuracy_score

# Compute the accuracy of the trained network on the training set
predict_train = model.predict(X_train)
accuracy_train = accuracy_score(y_train, predict_train)
print('Accuracy of the trained network on the training set: %.2f %%' % (100 * accuracy_train))

# Compute the accuracy of the train network on the test set
predict_test = model.predict(X_test)
accuracy_test = accuracy_score(y_test, predict_test)
print('Accuracy of the trained network on the test set: %.2f %%' % (100 * accuracy_test))
# Out:
# Iteration 1, loss = 2.22101082
# Iteration 2, loss = 0.54833434
# Iteration 3, loss = 0.37450186
#         -1.25138478e-02],
#        [ 8.66022494e-02,  2.18298003e-01,  7.13384391e-02,
#          8.67524631e-02,  1.00111344e-01,  1.04323448e-01,
#          1.27618351e-01,  7.51840083e-02,  1.61954209e-01,
#          5.26530944e-02]])]
# Biases =  [array([ 0.25027074,  0.03163501,  0.1317281 ,  0.01602667, -0.09294709,
#        -0.03317794,  0.00804698, -0.25398294, -0.08545177,  0.04966138,
#        -0.01062361,  0.07319514,  0.01618462,  0.02213778, -0.12581069,
#        -0.04661459, -0.05126165, -0.12393132, -0.0941215 ,  0.05321027,
#        -0.32269464, -0.07195482,  0.10009397,  0.10566236,  0.00393797,
#         0.25431453, -0.09252572,  0.01063851,  0.00434341,  0.28603457,
#        -0.10800128,  0.10007054,  0.04416499, -0.25636647,  0.03249078,
#        -0.02228944,  0.10633855, -0.12383934,  0.09176303, -0.02318221,
#        -0.11998283, -0.08588894,  0.10795998, -0.09508857, -0.01163109,
#         0.04226484, -0.27241443, -0.08630622,  0.02359616,  0.17222727,
#         0.03851637,  0.00707851,  0.04345805, -0.06414518, -0.33086078,
#        -0.07682095, -0.24008173, -0.00099297, -0.10909489,  0.25172214,
#         0.00838361, -0.19326589,  0.07296461,  0.01902892]), array([ 0.31124755, -0.20724935,  0.18760528, -0.05791901, -0.17146178,
#        -0.03798253,  0.68410564, -0.01812041,  0.59914404,  0.48613391,
#         0.14178508, -0.36615607, -0.23200883, -0.42249924, -0.29301554,
#        -0.10447194,  0.10126207,  0.14436208, -0.0024505 ,  0.18474843,
#        -0.01537345, -0.35686094,  0.09676402,  0.01577433, -0.23043285,
#        -0.10297653, -0.28070336, -0.01445554,  0.04758279,  0.01105857,
#         0.19062065, -0.08156927, -0.37746489, -0.03233027,  0.10904108,
#        -0.00910844,  0.11930172, -0.0236815 , -0.20707951,  0.13245336,
#         0.21504468,  0.30285474,  0.11171145,  0.41957993,  0.12181586,
#         0.12750332,  0.65877383,  0.03471485, -0.0836022 , -0.30124614,
#         0.00343908,  0.23874007,  0.17140904, -0.33431175, -0.16566943,
#        -0.0680637 , -0.34799239, -0.06670013, -0.0094337 , -0.38924791,
#        -0.31815059, -0.12299891, -0.09038556, -0.06025727]), array([ 0.01167773, -0.35231886,  0.12128493, -0.269608  ,  0.28501546,
#        -0.16753261, -0.26244819, -0.29277364,  0.07162139, -0.30252374,
#        -0.3326762 ,  0.06298082, -0.03071888, -0.06303723,  0.47420409,
#        -0.20507807, -0.35347979, -0.00591353,  0.10296491, -0.1051365 ,
#        -0.0446671 , -0.01557547, -0.02901427,  0.03133753,  0.05346993,
#         0.04711636, -0.190747  , -0.22416244, -0.28094076,  0.15121025,
#         0.08899969, -0.09556738]), array([-0.25361484, -0.4250082 ,  0.08970779, -0.65980523, -0.38600706,
#         0.5538339 , -0.13173798, -0.46844679,  1.63603884, -0.30922108])]
# Size of output layer:  10
# Activation function of output layer:  softmax
# Accuracy of the trained network on the training set: 99.54 %
# Accuracy of the trained network on the test set: 97.08 %
